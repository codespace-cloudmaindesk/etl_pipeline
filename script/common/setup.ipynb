# %%
# %sql
CREATE CATALOG IF NOT EXISTS abcgroup;
USE CATALOG abcgroup;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS abcgroup.gold;
CREATE SCHEMA IF NOT EXISTS abcgroup.silver;
CREATE SCHEMA IF NOT EXISTS abcgroup.bronze;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS abcgroup.bronze.raw_sources;
